# %% [markdown]
# <a href="https://colab.research.google.com/github/imaisnaini/data-science-2026/blob/main/Pertemuan1_Fatimah_Isnaini_Shabrina__250401020073.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📚 Practice 1 : Pengenalan Data Science
# ---
# ## 👩‍🎓 Student Information
#
# - **Name**: Fatimah Isnaini Shabrina
# - **NIM**: 250401020073
# - **University**: UNSIA - Universitas Siber Asia
# - **Class**: IF401 Data Science

# %% [markdown]
# ### SEL 1: Output sederhana

# %%
print("Hello, Data Science")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science
# Selamat datang di mata kuliah Pengantar Data Science!

# %% [markdown]
# ### SEL 2: Variabel dan tipe data dasar

# %%
nama = "Mahasiswa Informatika" # String
angkatan = 2026 # Integer
ipk = 3.75 # Float
aktif = True # Boolean

print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Nama : Mahasiswa Informatika
# Angkatan: 2026
# IPK : 3.75
# Aktif : True

# %% [markdown]
# ### SEL 3: List dan perulangan

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")

for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub

# %% [markdown]
# ### SEL 4: Fungsi sederhana

# %%
def perkenalan(nama, prodi, angkatan):
  return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Fatimah Isnaini Shabrina", "Informatika", 2026)
print(hasil)
# Out:
# Hai! Saya Fatimah Isnaini Shabrina dari Informatika, angkatan 2026.

# %% [markdown]
# ## 📝 Notes
#
# Pada pertemuan ini kita mempelajari :
# - Cara membuat Notebook di GoogleColab
# - Variable tipe dasar
# - List dan perulangan
# - Fungsi sederhana
