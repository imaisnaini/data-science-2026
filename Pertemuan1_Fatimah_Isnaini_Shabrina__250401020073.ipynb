# %% [markdown]
# <a href="https://colab.research.google.com/github/imaisnaini/data-science-2026/blob/main/Pertemuan1_Fatimah_Isnaini_Shabrina__250401020073.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Data Science")
# Out:
# Hello, Data Science

# %%
nama = "Mahasiswa Teknik Informatika"
angkatan = 2025

print(f"Hello {nama} angkatan {angkatan}!")
# Out:
# Hello Mahasiswa Teknik Informatika angkatan 2025!

# %%
tools = ["python", "colab", "jyupiter", "github"]

for i, tool in enumerate(tools, 1):
  print(f"{i}. {tool}")
# Out:
# 1. python
# 2. colab
# 3. jyupiter
# 4. github

# %%
def perkenalan(nama, prodi, angkatan):
  return f"{nama} dari {prodi} angkatan {angkatan}"

print(perkenalan("Fatimah Isnaini Shabrina", "Teknik Informatika", 2025))
# Out:
# Fatimah Isnaini Shabrina dari Teknik Informatika angkatan 2025
